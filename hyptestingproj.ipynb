# %%
import pandas as pd

# %%
import xlrd
xlsfile=pd.ExcelFile('SPEED.xls')

#workbook = xlrd.open_workbook('myxls.xls')
DF =xlsfile.parse('Sheet1')

# %%
DF
# Out:
#       iid    id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0       1   1.0       0    1       1     1     10         7       NaN      4
# 1       1   1.0       0    1       1     1     10         7       NaN      3
# 2       1   1.0       0    1       1     1     10         7       NaN     10
# 3       1   1.0       0    1       1     1     10         7       NaN      5
# 4       1   1.0       0    1       1     1     10         7       NaN      7
# 5       1   1.0       0    1       1     1     10         7       NaN      6
# 6       1   1.0       0    1       1     1     10         7       NaN      1
# 7       1   1.0       0    1       1     1     10         7       NaN      2
# 8       1   1.0       0    1       1     1     10         7       NaN      8
# 9       1   1.0       0    1       1     1     10         7       NaN      9
# 10      2   2.0       0    3       1     1     10         3       NaN     10
# ...

# %%
DF['attr1_1']
# Out:
# 0       15.0
# 1       15.0
# 2       15.0
# 3       15.0
# 4       15.0
# 5       15.0
# 6       15.0
# 7       15.0
# 8       15.0
# 9       15.0
# 10      45.0
# 11      45.0
# 12      45.0
# 13      45.0
# 14      45.0
# 15      45.0
# 16      45.0
# 17      45.0
# 18      45.0
# 19      45.0
# 20      35.0
# 21      35.0
# 22      35.0
# 23      35.0
# 24      35.0
# 25      35.0
# 26      35.0
# 27      35.0
# 28      35.0
# 29      35.0
#         ...
# 8348    40.0
# 8349    40.0
# 8350    40.0
# 8351    40.0
# 8352    40.0
# 8353    40.0
# 8354    40.0
# 8355    40.0
# 8356    70.0
# 8357    70.0
# 8358    70.0
# 8359    70.0
# 8360    70.0
# 8361    70.0
# 8362    70.0
# 8363    70.0
# 8364    70.0
# 8365    70.0
# 8366    70.0
# 8367    70.0
# 8368    70.0
# 8369    70.0
# 8370    70.0
# 8371    70.0
# 8372    70.0
# 8373    70.0
# 8374    70.0
# 8375    70.0
# 8376    70.0
# 8377    70.0
# Name: attr1_1, Length: 8378, dtype: float64

# %%
 DF['intel1_1'] #female 0 male 1
# Out:
# 0       20.0
# 1       20.0
# 2       20.0
# 3       20.0
# 4       20.0
# 5       20.0
# 6       20.0
# 7       20.0
# 8       20.0
# 9       20.0
# 10      25.0
# 11      25.0
# 12      25.0
# 13      25.0
# 14      25.0
# 15      25.0
# 16      25.0
# 17      25.0
# 18      25.0
# 19      25.0
# 20      35.0
# 21      35.0
# 22      35.0
# 23      35.0
# 24      35.0
# 25      35.0
# 26      35.0
# 27      35.0
# 28      35.0
# 29      35.0
#         ...
# 8348    20.0
# 8349    20.0
# 8350    20.0
# 8351    20.0
# 8352    20.0
# 8353    20.0
# 8354    20.0
# 8355    20.0
# 8356    15.0
# 8357    15.0
# 8358    15.0
# 8359    15.0
# 8360    15.0
# 8361    15.0
# 8362    15.0
# 8363    15.0
# 8364    15.0
# 8365    15.0
# 8366    15.0
# 8367    15.0
# 8368    15.0
# 8369    15.0
# 8370    15.0
# 8371    15.0
# 8372    15.0
# 8373    15.0
# 8374    15.0
# 8375    15.0
# 8376    15.0
# 8377    15.0
# Name: intel1_1, Length: 8378, dtype: float64

# %%
w_attr=[] # Kadın ların attr1 pointleri
b_attr=[] # erkeklerin attr1 pointleri

# %%
for i in range (0,8378):
    if(DF['gender'][i]==0):
        w_attr.append(DF['attr1_1'][i])
    else:
        b_attr.append(DF['attr1_1'][i])

# %%
w_intel=[]
b_intel=[]
for i in range (0,8378):
    if(DF['gender'][i]==0):
        w_intel.append(DF['intel1_1'][i])
    else:
        b_intel.append(DF['intel1_1'][i])

# %%
len(w_attr)
# Out:
# 4184

# %%
len(b_attr)
# Out:
# 4194

# %%
len(w_intel)
# Out:
# 4184

# %%
len(b_intel)
# Out:
# 4194

# %%
b_attr = b_attr[0:4184]
b_intel = b_intel[0:4184]

# %%
len(b_attr)
# Out:
# 4184

# %%
len(b_intel)
# Out:
# 4184

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats

# %%
from pandas import Series
women_attr = pd.Series(w_attr)
boy_attr=pd.Series(b_attr)

# %%
women_attr=women_attr.fillna(women_attr.mean())
boy_attr=boy_attr.fillna(boy_attr.mean())

# %%
(t, p) = stats.chisquare(women_attr, boy_attr, ddof=1)
print ('Test t=%f p-value = %f' % (t, p))

alpha = 0.05  # significance level
# Out:
# Test t=35842.684631 p-value = 0.000000

# %%
#two-tailed test
if p <= alpha/2:
    # we reject null hypothesis
    print ('Null hypothesis  is unlikely to except')
else:
    # we reject alternative hypothesis
    print ('Null hypothesis cannot be rejected')
# Out:
# Null hypothesis  is unlikely to except

# %%
from scipy import stats

# %%
t_stat, p_val = stats.ttest_ind(women_attr,boy_attr)
t_stat, p_val
# Out:
# (-34.43947106034647, 3.4380654612314287e-243)

# %%
#two-tailed test 
if p_val <= alpha/2:
    # we reject null hypothesis
    print ('Null hyptohesis is unlikely to except')
else:
    #we reject alternative hypothesis
    print ('Null hypothesis cannot be rejected')
# Out:
# Null hyptohesis is unlikely to except
